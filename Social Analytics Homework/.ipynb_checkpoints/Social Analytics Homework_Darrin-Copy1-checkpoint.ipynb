# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import json
from datetime import datetime
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret
import matplotlib.patches as mpatches


# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()


# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Account
target_user1 = "@BBC"

# Counter
counter1 = 1

# Variables for holding sentiments
sentiments1 = []

# Variable for max_id
oldest_tweet1 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets1 = api.user_timeline(target_user1, max_id = oldest_tweet1)

    # Loop through all tweets 
    for tweet in public_tweets1:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results1 = analyzer.polarity_scores(tweet["text"])
        compound1 = results1["compound"]
        pos1 = results1["pos"]
        neu1 = results1["neu"]
        neg1 = results1["neg"]
        tweets_ago1 = counter1
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet1 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments1.append({"Date": tweet["created_at"], 
                           "Compound": compound1,
                           "Positive": pos1,
                           "Negative": neu1,
                           "Neutral": neg1,
                           "Tweets Ago": counter1})
        
        # Add to counter 
        counter1 += 1

# Convert sentiments to DataFrame
sentiments_pd1 = pd.DataFrame.from_dict(sentiments1)
sentiments_pd1.head()

# Create plot
x_vals1 = sentiments_pd1["Tweets Ago"]
y_vals1 = sentiments_pd1["Compound"]
plt.plot(x_vals1,
         y_vals1, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
#now1 = datetime.now()
#now1 = now1.strftime("%Y-%m-%d %H:%M")
#plt.title(f"Sentiment Analysis of Tweets ({now1}) for {target_user1}")
#plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
#plt.ylabel("Tweet Polarity")
#plt.xlabel("Tweets Ago")
#plt.show()

# %%
# Target Account
target_user = "@CBS"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1

# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()

# Create plot
x_vals = sentiments_pd["Tweets Ago"]
y_vals = sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
#now = datetime.now()
#now = now.strftime("%Y-%m-%d %H:%M")
#plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user}")
#plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
#plt.ylabel("Tweet Polarity")
#plt.xlabel("Tweets Ago")
#plt.show()

# %%
# Target Account
target_user2 = "@CNN"

# Counter
counter2 = 1

# Variables for holding sentiments
sentiments2 = []

# Variable for max_id
oldest_tweet2 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets2 = api.user_timeline(target_user2, max_id = oldest_tweet2)

    # Loop through all tweets 
    for tweet in public_tweets2:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results2 = analyzer.polarity_scores(tweet["text"])
        compound2 = results2["compound"]
        pos2 = results2["pos"]
        neu2 = results2["neu"]
        neg2 = results2["neg"]
        tweets_ago2 = counter2
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet2 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments2.append({"Date": tweet["created_at"], 
                           "Compound": compound2,
                           "Positive": pos2,
                           "Negative": neu2,
                           "Neutral": neg2,
                           "Tweets Ago": counter2})
        
        # Add to counter 
        counter2 += 1

# Convert sentiments to DataFrame
sentiments_pd2 = pd.DataFrame.from_dict(sentiments2)
sentiments_pd2.head()

# Create plot
x_vals2 = sentiments_pd2["Tweets Ago"]
y_vals2 = sentiments_pd2["Compound"]
plt.plot(x_vals2,
         y_vals2, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
#now2 = datetime.now()
#now2= now2.strftime("%Y-%m-%d %H:%M")
#plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user}")
#plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
#plt.ylabel("Tweet Polarity")
#plt.xlabel("Tweets Ago")
#plt.show()

# %%
# Target Account
target_user3 = "@FoxNews"

# Counter
counter3 = 1

# Variables for holding sentiments
sentiments3 = []

# Variable for max_id
oldest_tweet3 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets3 = api.user_timeline(target_user3, max_id = oldest_tweet3)

    # Loop through all tweets 
    for tweet in public_tweets3:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results3 = analyzer.polarity_scores(tweet["text"])
        compound3 = results3["compound"]
        pos3 = results3["pos"]
        neu3 = results3["neu"]
        neg3 = results3["neg"]
        tweets_ago3 = counter3
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet3 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments3.append({"Date": tweet["created_at"], 
                           "Compound": compound3,
                           "Positive": pos3,
                           "Negative": neu3,
                           "Neutral": neg3,
                           "Tweets Ago": counter3})
        
        # Add to counter 
        counter3 += 1

# Convert sentiments to DataFrame
sentiments_pd3 = pd.DataFrame.from_dict(sentiments2)
sentiments_pd3.head()

# Create plot
x_vals3 = sentiments_pd3["Tweets Ago"]
y_vals3 = sentiments_pd3["Compound"]
plt.plot(x_vals3,
         y_vals3, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
#now2 = datetime.now()
#now2= now2.strftime("%Y-%m-%d %H:%M")
#plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user}")
#plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
#plt.ylabel("Tweet Polarity")
#plt.xlabel("Tweets Ago")
#plt.show()

# %%
# Target Account
target_user4 = "@nytimes"

# Counter
counter4 = 1

# Variables for holding sentiments
sentiments4 = []

# Variable for max_id
oldest_tweet4 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets4 = api.user_timeline(target_user4, max_id = oldest_tweet4)

    # Loop through all tweets 
    for tweet in public_tweets4:

        # Print Tweets
        # print("Tweet %s: %s" % (counter, tweet["text"]))
        
        # Run Vader Analysis on each tweet
        results4 = analyzer.polarity_scores(tweet["text"])
        compound4 = results4["compound"]
        pos4 = results4["pos"]
        neu4 = results4["neu"]
        neg4 = results4["neg"]
        tweets_ago2 = counter2
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet4 = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments4.append({"Date": tweet["created_at"], 
                           "Compound": compound4,
                           "Positive": pos4,
                           "Negative": neu4,
                           "Neutral": neg4,
                           "Tweets Ago": counter4})
        
        # Add to counter 
        counter4 += 1

# Convert sentiments to DataFrame
sentiments_pd4 = pd.DataFrame.from_dict(sentiments4)
sentiments_pd4.head()

# Create plot
x_vals4 = sentiments_pd4["Tweets Ago"]
y_vals4 = sentiments_pd4["Compound"]
plt.plot(x_vals4,
         y_vals4, marker="o", linewidth=0.5,
         alpha=0.8)

# # Incorporate the other graph properties
#now2 = datetime.now()
#now2= now2.strftime("%Y-%m-%d %H:%M")
#plt.title(f"Sentiment Analysis of Tweets ({now}) for {target_user}")
#plt.xlim([x_vals.max(),x_vals.min()]) #Bonus
#plt.ylabel("Tweet Polarity")
#plt.xlabel("Tweets Ago")
#plt.show()

# %%
# Create plot
x_vals = sentiments_pd["Tweets Ago"]
y_vals = sentiments_pd["Compound"]
plt.plot((x_vals1),
        (y_vals1), marker="o", linewidth=0.5,
         alpha=0.8, label = "CBS")
plt.plot((x_vals),
        (y_vals), marker="o", linewidth=0.5,
         alpha=0.8, label = "BBC")
plt.plot((x_vals2),
        (y_vals2), marker="o", linewidth=0.5,
         alpha=0.8, label = "CNN")
plt.plot((x_vals3),
        (y_vals3), marker="o", linewidth=0.5,
         alpha=0.8, label = "Fox")
plt.plot((x_vals4),
        (y_vals4), marker="o", linewidth=0.5,
         alpha=0.8, label = "New York Times")

# # Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%m/%d/%Y")
plt.title(f"Sentiment Analysis of Media Tweets ({now})")
plt.xlim([0,100])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")

#legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = "Media Sources")

plt.show()

# %%
#TRASH
#Tweet Times
target_user1 = "@BBC"
# Create array to record all date-times of tweets
tweet_times1 = []
counter1 = 0
# Loop through 500 tweets
for x in range(1, 6):
    
    # Get all tweets from target user
    public_tweets1 = api.user_timeline(target_user1, page=x)

    # Loop through all tweets
    for tweet in public_tweets1:

        # Store all tweet times into the array
        tweet_times1.append(tweet["created_at"])
        
        counter1 += 1
        
        # Print tweets for preview
        if counter1 % 100 == 0:
            print(tweet["created_at"])
# Confirm tweet counts
len(tweet_times1)
# Convert all tweet times into datetime objects
tweet_time_objects1 = []
# Add each datetime object into the array
for x in range(len(tweet_times1)):
    tweet_datetime1 = datetime.strptime(tweet_times1[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects1.append(tweet_datetime1)
    # Preview that datetimes are matching
    if x % 100 == 0:
        print(tweet_times1[x])
        print(tweet_datetime1)
# Calculate the time between tweets
time_in_between1 = []
# Calculate the time in between each tweet
for x in range(len(tweet_time_objects1)-1):
    hrs_apart1 = ((tweet_time_objects1[x] - tweet_time_objects1[x+1]).seconds) / 3600
    time_in_between1.append(hrs_apart1)
# Hours Between Tweets
print(f"Avg. Hours Between Tweets: {np.mean(time_in_between1)}")
time_in_between1[:10]
# Plot Time Between Tweets
plt.plot(range(len(time_in_between1)), time_in_between1, marker="o", 
               linewidth=0.25, alpha=0.8, color="r")
bbc, = plt.plot(range(len(time_in_between1)), time_in_between1, marker="o", 
               linewidth=0.25, alpha=0.8, color="r", label = "bbc")
plt.xlim([0, len(time_in_between1)])
plt.ylabel("Hours Apart")
plt.xlabel("Tweets Ago")
plt.title("Tweet Velocity: {target_user}")
plt.show()
len(tweet_times1)

# %%
#TRASH
#Tweet Times
target_user2 = "@CBS"
# Create array to record all date-times of tweets
tweet_times2 = []
counter2 = 0
# Loop through 500 tweets
for x in range(1, 6):
    
    # Get all tweets from target user
    public_tweets2 = api.user_timeline(target_user2, page=x)

    # Loop through all tweets
    for tweet in public_tweets2:

        # Store all tweet times into the array
        tweet_times2.append(tweet["created_at"])
        
        counter2 += 1
        
        # Print tweets for preview
        if counter2 % 100 == 0:
            print(tweet["created_at"])
# Confirm tweet counts
len(tweet_times2)
# Convert all tweet times into datetime objects
tweet_time_objects2 = []
# Add each datetime object into the array
for x in range(len(tweet_times2)):
    tweet_datetime2 = datetime.strptime(tweet_times2[x], "%a %b %d %H:%M:%S %z %Y")
    tweet_time_objects2.append(tweet_datetime2)
    # Preview that datetimes are matching
    if x % 100 == 0:
        print(tweet_times2[x])
        print(tweet_datetime2)
# Calculate the time between tweets
time_in_between2 = []
# Calculate the time in between each tweet
for x in range(len(tweet_time_objects2)-1):
    hrs_apart2 = ((tweet_time_objects2[x] - tweet_time_objects2[x+1]).seconds) / 3600
    time_in_between2.append(hrs_apart2)
# Hours Between Tweets
print(f"Avg. Hours Between Tweets: {np.mean(time_in_between2)}")
time_in_between2[:10]
# Plot Time Between Tweets
plt.plot(range(len(time_in_between2)), range(len(time_in_between2)), marker="o", 
               linewidth=0.25, alpha=0.8, color="r")
cbs, = plt.plot(range(len(time_in_between2)), time_in_between2, marker="o", 
               linewidth=0.25, alpha=0.8, color="r", label = "cbs")
plt.xlim([0, len(time_in_between2)])
plt.ylabel("Hours Apart")
plt.xlabel("Tweets Ago")
plt.title("Tweet Velocity: {target_user}")
plt.show()
len(tweet_times2)

# %%
#TRASH
# use the scatter function
#Create a plot to build upon
fig, ax = plt.subplots()
#add urban data to plot
for color in ['red']:
    l = 'bbc'
    x = range(len(time_in_between2))
    y = range(len(time_in_between2))
    z = np.mean(time_in_between2)
    ax.scatter(x, y, c=color, s=z*5, alpha=0.5, label=l, edgecolors='black')
#add suburban data to plot
#for color in ['yellow']:
#    l = 'Suburban'
#    x = city_rides_s
#    y = fair_avg_s
#    z = new_count_s
#    ax.scatter(x, y, c=color, s=z*5, alpha=0.5, label=l, edgecolors='black')
#add rural data to plot
#for color in ['blue']:
#    l = 'Rural'
#    x = city_rides_r
#    y = fair_avg_r
#    z = new_count_r
#    ax.scatter(x, y, c=color, s=z*5, alpha=0.5, label=l, edgecolors='black')

#create legend and set location, size, and title
legend = ax.legend(loc='upper right', fontsize='x-large', title="City Types") 
#Change the legend backround transparency to 100% transparency
legend.get_frame().set_alpha(0)
#ax.legend('rural','subuirban')

# set X limits of plot from 0 to 40
plt.xlim(0, 100)

# set y limits of plot from 15 to 45
plt.ylim(15, 45)

#adding a title
plt.title("Pyber Ride Sharing Data (2016)")
#Adding x and y labels
plt.xlabel("Total Number of Rides (Per City)")
plt.ylabel("Average Fares ($)")
#setting properties of gridlines for color, transparency, linestyles and width
ax.grid(color='w', alpha=.2, linestyle='-', linewidth=2)
#setting background color of plot
ax.set_facecolor('xkcd:light grey')
#pushing the gridlines behind the plotted points
ax.set_axisbelow(True)

#Adding note to the right of the plot
left, width = .6, .5
bottom, height = .25, .5
right = left + width
top = bottom + height
ax.text(right, 0.5*(bottom+top), 'Note:'+ "\n" + "Circle size correlates with driver count per city.",
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=12,
        transform=ax.transAxes)

plt.show()
#review legends pyplot legend legend handles

# %%
#Second plot
# Target Search Term
target_terms = ("@BBC", "@CBS", "@CNN","@FoxNews", "@nytimes")
# "Real Person" Filters
#min_tweets = 5
#max_tweets = 10000
#max_followers = 2500
#max_following = 2500
#lang = "en"

# List to hold results
results_list = []

# Loop through all target users
for target in target_terms:

    # Variable for holding the oldest tweet
    oldest_tweet = None

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Loop through 10 times
    for x in range(20):

        # Run search around each tweet
        public_tweets = api.search(
            target, count=5, result_type="recent", max_id=oldest_tweet)

        # Loop through all tweets
        for tweet in public_tweets["statuses"]:
            while len(compound_list) < 100:
            # Use filters to check if user meets conditions
            #if (tweet["user"]["followers_count"] < max_followers
            #    and tweet["user"]["statuses_count"] > min_tweets
            #    and tweet["user"]["statuses_count"] < max_tweets
            #    and tweet["user"]["friends_count"] < max_following
            #    and tweet["user"]["lang"] == lang):

            # Run Vader Analysis on each tweet
                results = analyzer.polarity_scores(tweet["text"])
                compound = results["compound"]
                pos = results["pos"]
                neu = results["neu"]
                neg = results["neg"]

            # Add each value to the appropriate list
                compound_list.append(compound)
                positive_list.append(pos)
                negative_list.append(neg)
                neutral_list.append(neu)
                
            # Set the new oldest_tweet value
                oldest_tweet = tweet["id"] - 1

    # Store the Average Sentiments
    sentiment = {
        "User": target,
        "Compound": np.mean(compound_list),
        "Positive": np.mean(positive_list),
        "Neutral": np.mean(negative_list),
        "Negative": np.mean(neutral_list),
        "Tweet Count": len(compound_list)
    }

    # Print the Sentiments
    print(sentiment)
    print()
    
    # Append airline results to 'results_list'
    results_list.append(sentiment)
# Out:
# {'User': '@BBC', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 0.0, 'Negative': 1.0, 'Tweet Count': 2}
# C:\Users\Mattress IT\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\numpy\core\fromnumeric.py:2957: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Mattress IT\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# {'User': '@CBS', 'Compound': nan, 'Positive': nan, 'Neutral': nan, 'Negative': nan, 'Tweet Count': 0}
#
# {'User': '@CNN', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 0.0, 'Negative': 1.0, 'Tweet Count': 2}
#
# {'User': '@FoxNews', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 0.0, 'Negative': 1.0, 'Tweet Count': 2}
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# ...

# %%
#TRASH
# Loop through all tweets
for tweet in public_tweets:
    raw_time = tweet["created_at"]
    print(raw_time)
    tweet_times.append(raw_time)

# %%
tweet_df = pd.DataFrame(results_list).set_index("User").round(3)
tweet_df
# Out:
#           Compound  Negative  Neutral  Positive  Tweet Count
# User
# @BBC         0.000     1.000    0.000     0.000          100
# @CBS         0.422     0.859    0.000     0.141          100
# @CNN         0.750     0.796    0.000     0.204          100
# @FoxNews    -0.128     0.939    0.061     0.000          100
# @nytimes     0.000     1.000    0.000     0.000          100

# %%
my_plot = tweet_df['Compound'].plot(kind='bar', title = "Overall Media Sentiment based on Twitter")
my_plot.set_xlabel("Twitter account")
my_plot.set_ylabel("Tweet Polarity")
# Out:
# Text(0,0.5,'Tweet Polarity')
