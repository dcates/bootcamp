# %%
#obversable trends
#1:BBC tends to have more Positive tweets overall
#2:CNN tends to have more Positive tweets overall
#3:Fox News tends to have more negative tweets overall

# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
import json
from datetime import datetime
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret
import matplotlib.patches as mpatches
import time

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Account
target_user1 = "@BBC"

# Counter
counter1 = 1

# Variables for holding sentiments
sentiments1 = []

# Variable for max_id
oldest_tweet1 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets1 = api.user_timeline(target_user1, max_id = oldest_tweet1)

    # Loop through all tweets 
    for tweet1 in public_tweets1:
        
        # Run Vader Analysis on each tweet
        results1 = analyzer.polarity_scores(tweet1["text"])
        compound1 = results1["compound"]
        pos1 = results1["pos"]
        neu1 = results1["neu"]
        neg1 = results1["neg"]
        tweets_ago1 = counter1
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet1 = tweet1['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments1.append({"Date": tweet1["created_at"], 
                           "Compound": compound1,
                           "Positive": pos1,
                           "Negative": neu1,
                           "Neutral": neg1,
                           "Tweets Ago": counter1})
        
        # Add to counter 
        counter1 += 1

# Convert sentiments to DataFrame
sentiments_pd1 = pd.DataFrame.from_dict(sentiments1)
sentiments_pd1.head()

# Create plot
x_vals1 = sentiments_pd1["Tweets Ago"]
y_vals1 = sentiments_pd1["Compound"]
plt.plot(x_vals1,
         y_vals1, marker="o", linewidth=0.5,
         alpha=0.8)
plt.savefig('BBC.png')

# %%
# Target Account
target_user = "@CBS"

# Counter
counter = 1

# Variables for holding sentiments
sentiments = []

# Variable for max_id
oldest_tweet = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets = api.user_timeline(target_user, max_id = oldest_tweet)

    # Loop through all tweets 
    for tweet in public_tweets:

        # Run Vader Analysis on each tweet
        results = analyzer.polarity_scores(tweet["text"])
        compound = results["compound"]
        pos = results["pos"]
        neu = results["neu"]
        neg = results["neg"]
        tweets_ago = counter
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet = tweet['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        # Add to counter 
        counter += 1

# Convert sentiments to DataFrame
sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()

# Create plot
x_vals = sentiments_pd["Tweets Ago"]
y_vals = sentiments_pd["Compound"]
plt.plot(x_vals,
         y_vals, marker="o", linewidth=0.5,
         alpha=0.8)
plt.savefig('CBS.png')

# %%
# Target Account
target_user2 = "@CNN"

# Counter
counter2 = 1

# Variables for holding sentiments
sentiments2 = []

# Variable for max_id
oldest_tweet2 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets2 = api.user_timeline(target_user2, max_id = oldest_tweet2)

    # Loop through all tweets 
    for tweet2 in public_tweets2:
       
        # Run Vader Analysis on each tweet
        results2 = analyzer.polarity_scores(tweet2["text"])
        compound2 = results2["compound"]
        pos2 = results2["pos"]
        neu2 = results2["neu"]
        neg2 = results2["neg"]
        tweets_ago2 = counter2
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet2 = tweet2['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments2.append({"Date": tweet2["created_at"], 
                           "Compound": compound2,
                           "Positive": pos2,
                           "Negative": neu2,
                           "Neutral": neg2,
                           "Tweets Ago": counter2})
        
        # Add to counter 
        counter2 += 1

# Convert sentiments to DataFrame
sentiments_pd2 = pd.DataFrame.from_dict(sentiments2)
sentiments_pd2.head()

# Create plot
x_vals2 = sentiments_pd2["Tweets Ago"]
y_vals2 = sentiments_pd2["Compound"]
plt.plot(x_vals2,
         y_vals2, marker="o", linewidth=0.5,
         alpha=0.8)
plt.savefig('CNN.png')

# %%
# Target Account
target_user3 = "@FoxNews"

# Counter
counter3 = 1

# Variables for holding sentiments
sentiments3 = []

# Variable for max_id
oldest_tweet3 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets3 = api.user_timeline(target_user3, max_id = oldest_tweet3)

    # Loop through all tweets 
    for tweet3 in public_tweets3:
        
        # Run Vader Analysis on each tweet
        results3 = analyzer.polarity_scores(tweet3["text"])
        compound3 = results3["compound"]
        pos3 = results3["pos"]
        neu3 = results3["neu"]
        neg3 = results3["neg"]
        tweets_ago3 = counter3
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet3 = tweet3['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments3.append({"Date": tweet3["created_at"], 
                           "Compound": compound3,
                           "Positive": pos3,
                           "Negative": neu3,
                           "Neutral": neg3,
                           "Tweets Ago": counter3})
        
        # Add to counter 
        counter3 += 1

# Convert sentiments to DataFrame
sentiments_pd3 = pd.DataFrame.from_dict(sentiments2)
sentiments_pd3.head()

# Create plot
x_vals3 = sentiments_pd3["Tweets Ago"]
y_vals3 = sentiments_pd3["Compound"]
plt.plot(x_vals3,
         y_vals3, marker="o", linewidth=0.5,
         alpha=0.8)
plt.savefig('Fox News.png')

# %%
# Target Account
target_user4 = "@nytimes"

# Counter
counter4 = 1

# Variables for holding sentiments
sentiments4 = []

# Variable for max_id
oldest_tweet4 = None

# Loop through 5 pages of tweets (total 100 tweets)
for x in range(5):

    # Get all tweets from home feed
    public_tweets4 = api.user_timeline(target_user4, max_id = oldest_tweet4)

    # Loop through all tweets 
    for tweet4 in public_tweets4:
        
        # Run Vader Analysis on each tweet
        results4 = analyzer.polarity_scores(tweet4["text"])
        compound4 = results4["compound"]
        pos4 = results4["pos"]
        neu4 = results4["neu"]
        neg4 = results4["neg"]
        tweets_ago2 = counter2
        
        # Get Tweet ID, subtract 1, and assign to oldest_tweet
        oldest_tweet4 = tweet4['id'] - 1
        
        # Add sentiments for each tweet into a list
        sentiments4.append({"Date": tweet4["created_at"], 
                           "Compound": compound4,
                           "Positive": pos4,
                           "Negative": neu4,
                           "Neutral": neg4,
                           "Tweets Ago": counter4})
        
        # Add to counter 
        counter4 += 1

# Convert sentiments to DataFrame
sentiments_pd4 = pd.DataFrame.from_dict(sentiments4)
sentiments_pd4.head()

# Create plot
x_vals4 = sentiments_pd4["Tweets Ago"]
y_vals4 = sentiments_pd4["Compound"]
plt.plot(x_vals4,
         y_vals4, marker="o", linewidth=0.5,
         alpha=0.8)
plt.savefig('New York Times.png')

# %%
# Create plot
x_vals = sentiments_pd["Tweets Ago"]
y_vals = sentiments_pd["Compound"]
plt.plot((x_vals1),
        (y_vals1), marker="o", linewidth=0.5,
         alpha=0.8, label = "BBC")
plt.plot((x_vals),
        (y_vals), marker="o", linewidth=0.5,
         alpha=0.8, label = "CBS")
plt.plot((x_vals2),
        (y_vals2), marker="o", linewidth=0.5,
         alpha=0.8, label = "CNN")
plt.plot((x_vals3),
        (y_vals3), marker="o", linewidth=0.5,
         alpha=0.8, label = "Fox")
plt.plot((x_vals4),
        (y_vals4), marker="o", linewidth=0.5,
         alpha=0.8, label = "New York Times")

# # Incorporate the other graph properties
now = datetime.now()
now = now.strftime("%m/%d/%Y")
plt.title(f"Sentiment Analysis of Media Tweets ({now})")
plt.xlim([0,100])
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")

#legend
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title = "Media Sources")
plt.savefig('Media Tweets.png')
plt.show()

# %%
#Second plot
# Target Search Term
target_terms = ("@BBC", "@CBS", "@CNN","@FoxNews", "@nytimes")

# List to hold results
results_list = []

# Loop through all target users
for target in target_terms:

    # Variable for holding the oldest tweet
    oldest_tweet = None

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []

    # Loop through
    for x in range(20):
        time.sleep(2)
        # Run search around each tweet
        public_tweets = api.search(
            target, count=5, result_type="recent", max_id=oldest_tweet)

        # Loop through all tweets
        for tweet in public_tweets["statuses"]:
            while len(compound_list) < 100:

            # Run Vader Analysis on each tweet
                results = analyzer.polarity_scores(tweet["text"])
                compound = results["compound"]
                pos = results["pos"]
                neu = results["neu"]
                neg = results["neg"]

            # Add each value to the appropriate list
                compound_list.append(compound)
                positive_list.append(pos)
                negative_list.append(neg)
                neutral_list.append(neu)
                
            # Set the new oldest_tweet value
                oldest_tweet = tweet["id"] - 1

    # Store the Average Sentiments
    sentiment = {
        "User": target,
        "Compound": np.mean(compound_list),
        "Positive": np.mean(positive_list),
        "Neutral": np.mean(negative_list),
        "Negative": np.mean(neutral_list),
        "Tweet Count": len(compound_list)
    }

    # Print the Sentiments
    print(sentiment)
    print()
    
    # Append airline results to 'results_list'
    results_list.append(sentiment)
# Out:
# {'User': '@BBC', 'Compound': 0.765, 'Positive': 0.292, 'Neutral': 0.0, 'Negative': 0.708, 'Tweet Count': 100}
#
# {'User': '@CBS', 'Compound': 0.0, 'Positive': 0.0, 'Neutral': 0.0, 'Negative': 1.0, 'Tweet Count': 100}
#
# {'User': '@CNN', 'Compound': 0.5859, 'Positive': 0.15799999999999995, 'Neutral': 0.053000000000000005, 'Negative': 0.7889999999999999, 'Tweet Count': 100}
#
# {'User': '@FoxNews', 'Compound': -0.7783, 'Positive': 0.0, 'Neutral': 0.4930000000000001, 'Negative': 0.5069999999999998, 'Tweet Count': 100}
#
# {'User': '@nytimes', 'Compound': -0.7184000000000001, 'Positive': 0.0, 'Neutral': 0.24, 'Negative': 0.7600000000000001, 'Tweet Count': 100}

# %%
tweet_df = pd.DataFrame(results_list).set_index("User").round(3)
tweet_df.to_csv('tweet data.csv')
tweet_df
# Out:
#           Compound  Negative  Neutral  Positive  Tweet Count
# User
# @BBC         0.765     0.708    0.000     0.292          100
# @CBS         0.000     1.000    0.000     0.000          100
# @CNN         0.586     0.789    0.053     0.158          100
# @FoxNews    -0.778     0.507    0.493     0.000          100
# @nytimes    -0.718     0.760    0.240     0.000          100

# %%
my_plot = tweet_df['Compound'].plot(kind='bar', title = "Overall Media Sentiment based on Twitter")
my_plot.set_xlabel("Twitter account")
my_plot.set_ylabel("Tweet Polarity")
plt.savefig('Overall Media Sentiment.png')
